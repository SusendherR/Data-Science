# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
dataset=pd.read_csv("Placement.csv")

# %%
dataset
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0        1      M  67.00   Others  91.00   Others  Commerce     58.00
# 1        2      M  79.33  Central  78.33   Others   Science     77.48
# 2        3      M  65.00  Central  68.00  Central      Arts     64.00
# 3        4      M  56.00  Central  52.00  Central   Science     52.00
# 4        5      M  85.80  Central  73.60  Central  Commerce     73.30
# ..     ...    ...    ...      ...    ...      ...       ...       ...
# 210    211      M  80.60   Others  82.00   Others  Commerce     77.60
# 211    212      M  58.00   Others  60.00   Others   Science     72.00
# 212    213      M  67.00   Others  67.00   Others  Commerce     73.00
# 213    214      F  74.00   Others  66.00   Others  Commerce     58.00
# 214    215      M  62.00  Central  58.00   Others   Science     53.00
#
#       degree_t workex  etest_p specialisation  mba_p      status    salary
# ...

# %%
# rowand colums identification 
print ("the number of Row:",dataset.shape[0])
print("the number of column:",dataset.shape[1])
# Out:
# the number of Row: 215
# the number of column: 15

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 215 entries, 0 to 214
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   sl_no           215 non-null    int64
#  1   gender          215 non-null    object
#  2   ssc_p           215 non-null    float64
#  3   ssc_b           215 non-null    object
#  4   hsc_p           215 non-null    float64
#  5   hsc_b           215 non-null    object
#  6   hsc_s           215 non-null    object
#  7   degree_p        215 non-null    float64
#  8   degree_t        215 non-null    object
#  9   workex          215 non-null    object
#  10  etest_p         215 non-null    float64
#  11  specialisation  215 non-null    object
#  12  mba_p           215 non-null    float64
#  13  status          215 non-null    object
#  14  salary          148 non-null    float64
# dtypes: float64(6), int64(1), object(8)
# memory usage: 25.3+ KB

# %%
#First we check null or nan values are there
dataset.isnull().sum()
#dataset.isna().sum()
# Out:
# sl_no              0
# gender             0
# ssc_p              0
# ssc_b              0
# hsc_p              0
# hsc_b              0
# hsc_s              0
# degree_p           0
# degree_t           0
# workex             0
# etest_p            0
# specialisation     0
# mba_p              0
# status             0
# salary            67
# dtype: int64

# %% [markdown]
# # What are the different methods to preprocess the data using Data Preprocessing

# %% [markdown]
# 1) 1)Replace the missing value with central tendency: mean, median, mode.
# 2) 2)Delete the entire row.
# 3) 3)With respect to the problem, we have to replace the missing values.
# 4) 4)Consider this as semi-supervised; create a model so that we can predict the missing values.
# 5) 5)Replace missing values using The three methods.

# %% [markdown]
# # 1.Replace the NaN values with correct values .And Justify why you have chosen the same

# %% [markdown]
# 1. The dataset has a null value of 67.
# 2. Using the fillna method, we replace the value because a student who is not placed cannot get a salary.
# 3. So we use this method to fill null values with zero.

# %%
# nall value replace inplace=True you can store the dataset
dataset["salary"].fillna(0,inplace=True)

# %%
# The zero value is being displayed.
dataset.isnull().sum()
# Out:
# sl_no             0
# gender            0
# ssc_p             0
# ssc_b             0
# hsc_p             0
# hsc_b             0
# hsc_s             0
# degree_p          0
# degree_t          0
# workex            0
# etest_p           0
# specialisation    0
# mba_p             0
# status            0
# salary            0
# dtype: int64

# %%
dataset.drop("sl_no",inplace=True,axis=1)
dataset
# Out:
#     gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p   degree_t  \
# 0        M  67.00   Others  91.00   Others  Commerce     58.00   Sci&Tech
# 1        M  79.33  Central  78.33   Others   Science     77.48   Sci&Tech
# 2        M  65.00  Central  68.00  Central      Arts     64.00  Comm&Mgmt
# 3        M  56.00  Central  52.00  Central   Science     52.00   Sci&Tech
# 4        M  85.80  Central  73.60  Central  Commerce     73.30  Comm&Mgmt
# ..     ...    ...      ...    ...      ...       ...       ...        ...
# 210      M  80.60   Others  82.00   Others  Commerce     77.60  Comm&Mgmt
# 211      M  58.00   Others  60.00   Others   Science     72.00   Sci&Tech
# 212      M  67.00   Others  67.00   Others  Commerce     73.00  Comm&Mgmt
# 213      F  74.00   Others  66.00   Others  Commerce     58.00  Comm&Mgmt
# 214      M  62.00  Central  58.00   Others   Science     53.00  Comm&Mgmt
#
#     workex  etest_p specialisation  mba_p      status    salary
# ...

# %% [markdown]
# # 2)How many of them are not placed ?

# %%
dataset["status"].value_counts()['Not Placed']
# Out:
# 67

# %%
# 67 Studends not placed

# %% [markdown]
# # 3)Find the reason for non placement from the dataset

# %%
data=dataset[dataset['status']=='Not Placed']

# %%
data
# Out:
#     gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p   degree_t  \
# 3        M   56.0  Central   52.0  Central   Science     52.00   Sci&Tech
# 5        M   55.0   Others   49.8   Others   Science     67.25   Sci&Tech
# 6        F   46.0   Others   49.2   Others  Commerce     79.00  Comm&Mgmt
# 9        M   58.0  Central   70.0  Central  Commerce     61.00  Comm&Mgmt
# 12       F   47.0  Central   55.0   Others   Science     65.00  Comm&Mgmt
# ..     ...    ...      ...    ...      ...       ...       ...        ...
# 198      F   67.0  Central   70.0  Central  Commerce     65.00     Others
# 201      M   54.2  Central   63.0   Others   Science     58.00  Comm&Mgmt
# 206      M   41.0  Central   42.0  Central   Science     60.00  Comm&Mgmt
# 208      F   43.0  Central   60.0   Others   Science     65.00  Comm&Mgmt
# 214      M   62.0  Central   58.0   Others   Science     53.00  Comm&Mgmt
#
#     workex  etest_p specialisation  mba_p      status  salary
# ...

# %%
data['ssc_b'].dtypes
# Out:
# dtype('O')

# %%
def quanQual(data):
    quan=[]
    qual=[]
    for columnName in dataset.columns:
    #print(columnName)
        if(data[columnName].dtype=='O'):
        #print("qual")
            qual.append(columnName)
        else:
        #print("quan")
            quan.append(columnName)
    return quan,qual

# %%
quan,qual=quanQual(data)

# %%
quan
# Out:
# ['ssc_p', 'hsc_p', 'degree_p', 'etest_p', 'mba_p', 'salary']

# %%
descriptive=pd.DataFrame(index=["median"],columns=quan)
for columnName in quan:
    descriptive[columnName]["median"]=data[columnName].median()

# %%
descriptive
# Out:
#         ssc_p  hsc_p degree_p etest_p  mba_p salary
# median  56.28  60.33     61.0    67.0  60.69    0.0

# %%
data1=dataset[dataset['status']=='Placed']

# %%
data1
# Out:
#     gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p   degree_t  \
# 0        M  67.00   Others  91.00   Others  Commerce     58.00   Sci&Tech
# 1        M  79.33  Central  78.33   Others   Science     77.48   Sci&Tech
# 2        M  65.00  Central  68.00  Central      Arts     64.00  Comm&Mgmt
# 4        M  85.80  Central  73.60  Central  Commerce     73.30  Comm&Mgmt
# 7        M  82.00  Central  64.00  Central   Science     66.00   Sci&Tech
# ..     ...    ...      ...    ...      ...       ...       ...        ...
# 209      M  62.00  Central  72.00  Central  Commerce     65.00  Comm&Mgmt
# 210      M  80.60   Others  82.00   Others  Commerce     77.60  Comm&Mgmt
# 211      M  58.00   Others  60.00   Others   Science     72.00   Sci&Tech
# 212      M  67.00   Others  67.00   Others  Commerce     73.00  Comm&Mgmt
# 213      F  74.00   Others  66.00   Others  Commerce     58.00  Comm&Mgmt
#
#     workex  etest_p specialisation  mba_p  status    salary
# ...

# %%
def quanQual(data1):
    quan1=[]
    qual1=[]
    for columnName in data.columns:
    #print(columnName)
        if(data1[columnName].dtype=='O'):
        #print("qual")
            qual1.append(columnName)
        else:
        #print("quan")
            quan1.append(columnName)
    return quan1,qual1

# %%
quan1,qual1=quanQual(data1)

# %%
quan1
# Out:
# ['ssc_p', 'hsc_p', 'degree_p', 'etest_p', 'mba_p', 'salary']

# %%
descriptive=pd.DataFrame(index=["median"],columns=quan1)
for columnName in quan1:
    descriptive[columnName]["median"]=data1[columnName].median()

# %%
descriptive
# Out:
#        ssc_p hsc_p degree_p etest_p   mba_p    salary
# median  72.5  68.0     68.0    72.0  62.245  265000.0

# %% [markdown]
# # Find the reason for non placement
#   Not placed students: Up to SSC_P mark, the ETEST_P mark is under 68%. Students with below 68% pass marks are not placed.
#
#   Placed students: SSC_P to ETEST_P marks above or equal to 68% pass marks are job placed.

# %% [markdown]
# # 4) What kind of relation between salary and mba_p

# %%
# using the Correlation 
dataset.corr(numeric_only=True)
# Out:
#              ssc_p     hsc_p  degree_p   etest_p     mba_p    salary
# ssc_p     1.000000  0.511472  0.538404  0.261993  0.388478  0.538090
# hsc_p     0.511472  1.000000  0.434206  0.245113  0.354823  0.452569
# degree_p  0.538404  0.434206  1.000000  0.224470  0.402364  0.408371
# etest_p   0.261993  0.245113  0.224470  1.000000  0.218055  0.186988
# mba_p     0.388478  0.354823  0.402364  0.218055  1.000000  0.139823
# salary    0.538090  0.452569  0.408371  0.186988  0.139823  1.000000

# %% [markdown]
#  # What kind of relation between salary and mba_p-Justify
#   Correlation - difference between 2 Colum.
#   Correlation between  salary,mba_p mark 13%  proportional positive Correlation

# %% [markdown]
# # 5)Which specialization is getting minimum salary?

# %%
data1.sort_values(by="salary",ascending =True)
# Out:
#     gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p   degree_t  \
# 107      M  82.00   Others  90.00   Others  Commerce     83.00  Comm&Mgmt
# 1        M  79.33  Central  78.33   Others   Science     77.48   Sci&Tech
# 135      F  72.00  Central  56.00   Others   Science     69.00  Comm&Mgmt
# 50       F  75.20  Central  73.20  Central   Science     68.40  Comm&Mgmt
# 44       F  77.00   Others  73.00   Others  Commerce     81.00  Comm&Mgmt
# ..     ...    ...      ...    ...      ...       ...       ...        ...
# 163      M  63.00   Others  67.00   Others   Science     64.00   Sci&Tech
# 77       M  64.00   Others  80.00   Others   Science     65.00   Sci&Tech
# 177      F  73.00  Central  97.00   Others  Commerce     79.00  Comm&Mgmt
# 150      M  71.00  Central  58.66  Central   Science     58.00   Sci&Tech
# 119      M  60.80  Central  68.40  Central  Commerce     64.60  Comm&Mgmt
#
#     workex  etest_p specialisation  mba_p  status    salary
# ...

# %% [markdown]
#  # Which specialization is getting minimum salary?
#     The minimum salary for the specialization in Marketing and Human Resources is 200,000.

# %% [markdown]
# # 6)How many of them getting above 500000 salary ?

# %%
val=dataset[dataset['salary'] > 500000]
val
# Out:
#     gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p   degree_t  \
# 119      M   60.8  Central  68.40  Central  Commerce      64.6  Comm&Mgmt
# 150      M   71.0  Central  58.66  Central   Science      58.0   Sci&Tech
# 177      F   73.0  Central  97.00   Others  Commerce      79.0  Comm&Mgmt
#
#     workex  etest_p specialisation  mba_p  status    salary
# 119    Yes    82.66        Mkt&Fin  64.34  Placed  940000.0
# 150    Yes    56.00        Mkt&Fin  61.30  Placed  690000.0
# 177    Yes    89.00        Mkt&Fin  70.81  Placed  650000.0

# %% [raw]
# (or)
# above5lack=[]
# for i in dataset["salary"]:
#     if(i>500000):
#         above5lack.append(i)
# print(above5lack)
#
# 3 number of above 5 lack salary person

# %%
val.count()
# Out:
# gender            3
# ssc_p             3
# ssc_b             3
# hsc_p             3
# hsc_b             3
# hsc_s             3
# degree_p          3
# degree_t          3
# workex            3
# etest_p           3
# specialisation    3
# mba_p             3
# status            3
# salary            3
# dtype: int64

# %% [markdown]
# # How many of them getting above 500000 salary ?
#  Three people with a salary above five lakhs.

# %% [markdown]
# # 7)Test the Analysis of variance between etest_p and mba_p at significance level 5% (Make decision using Hypothesis testing )

# %%
import scipy.stats as stats
stats.f_oneway(dataset["etest_p"],dataset["mba_p"])
# Out:
# F_onewayResult(statistic=98.64487057324706, pvalue=4.672547689133573e-21)

# %% [markdown]
# H0-There is no signification between this colums
# H1-There is signification between this colums
# Accept H0 ,Reject H1

# %% [markdown]
# # Analysis of Variance-Justify
#   The p-value is under 5%. So, accept H0 and reject H1.

# %% [markdown]
# # 8)Test the similarity between the degree_t(Sci&Tech) and specialization(Mkt&HR) with respect to salary at significant level of 5%(Make decision using Hypothesis testing)

# %% [markdown]
# Independent Sample-Unpaired T Test. Different group(degree_t,specialisation)but same condition(salary)

# %%
from scipy.stats import ttest_ind
#drop null values
dataset=dataset.dropna()
degree=dataset[dataset["degree_t"]=="Sci&Tech"]["salary"]
spec=dataset[dataset["specialisation"]=="Mkt&HR"]["salary"]

ttest_ind(degree,spec)
# Out:
# Ttest_indResult(statistic=2.692041243555374, pvalue=0.007897969943471179)

# %% [markdown]
# Hypothesis testing. Statement: Test the similarity between the degree_t (Sci & Tech) and specialization (Mkt & HR) with respect to salary. Alternative hypothesis: There is similarity between the degree_t of Sci & Tech and the specialization of Mkt & HR.
#
# The p-value is less than 5%, so we accept the alternative hypothesis and reject the null hypothesis.

# %% [markdown]
# # 9)Convert the normal distribution to standardnormal distribution for salary columns

# %%
def stdNBgraph(dataset):
    import seaborn as sns
    #calculate the mean,std
    mean=dataset.mean()
    std=dataset.std()
    # advantage of single line output converted to the list 
    values=[i for i in dataset]
    z_score=[((j-mean)/std) for j in values]
    # kde(Kernel density function)=True the curve will diply
    sns.distplot(z_score,kde=True)
    sum(z_score)/len(z_score)

# %%
stdNBgraph(dataset["salary"])
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_15800\1360798016.py:10: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(z_score,kde=True)
# C:\Users\DELL\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
import seaborn as sb
sb.distplot(dataset['ssc_p'],hist=True,kde=True,kde_kws={'color':'red'})
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_15800\875866881.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sb.distplot(dataset['ssc_p'],hist=True,kde=True,kde_kws={'color':'red'})
# C:\Users\DELL\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='ssc_p', ylabel='Density'>

# %% [markdown]
# # 10)What is the probability Density Function of the salary range from 700000 to 900000 ?

# %%
def get_pdf_probability(dataset,startrange,endrange):
    # import the importance of library
    from matplotlib import pyplot
    # inbuilt function for normal distribution library
    from scipy.stats import norm
    # vizualization representation
    import seaborn as sns
    # distplot is kde(Kernel density function)=True the curve will diply ,false the curve will the be not disply
    ax = sns.distplot(dataset,kde=True,kde_kws={'color':'Green'},color='yellow')
    # axvline is virtical line startrange color
    pyplot.axvline(startrange,color='Red')
    # axvline is virtical line endrange color
    pyplot.axvline(endrange,color='Red')
    # above this line the graph creating 
    # Below lines for calculation
    # generate a sample
    sample=dataset
    # calculate the mean,std parameters 
    sample_mean=sample.mean()
    sample_std=sample.std()
    # print the mean ,std
    print('Mean=%.3f,Standard Deviation=%.3f'%(sample_mean,sample_std))
    # define the distribution
    # There is the normal distribution funcation.lear distributionPattern 
    dist=norm(sample_mean,sample_std)
    
    # sample probabilities for a range of outcomes
    # advantage of below line is in single line the output it  is converted into list it is call to one-liner for loop
    values = [value for value in range(startrange, endrange)]
    # whole probabilities summation the below lines
    probabilities = [dist.pdf(value) for value in values]    
    prob=sum(probabilities)
    print("The area between range({},{}):{}".format(startrange,endrange,sum(probabilities)))
    return prob

# %%
get_pdf_probability(dataset["salary"],700000,900000)
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_15800\891670841.py:9: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax = sns.distplot(dataset,kde=True,kde_kws={'color':'Green'},color='yellow')
# C:\Users\DELL\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# Mean=198702.326,Standard Deviation=154780.927
# The area between range(700000,900000):0.0005973310593974901
# 0.0005973310593974901

# %%
sb.jointplot(x='ssc_p',y='salary',data=dataset)
plt.show()
# Out:
# C:\Users\DELL\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\DELL\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
sb.jointplot(x='ssc_p',y='salary',data=dataset,kind='hex')
plt.show()
# Out:
# C:\Users\DELL\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\DELL\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
sb.jointplot(x='ssc_p',y='salary',data=dataset,kind='kde')
plt.show()
# Out:
# C:\Users\DELL\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\DELL\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\DELL\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %% [markdown]
# # 11)Test the similarity between the degree_t(sci&Tech) with respect to etest_p and mba_p at significance level of 5%(Make decision using Hypothesis Testing)

# %% [markdown]
# Dependent sample-Paired T Test. Same group(degree_t)but Different condition(etest
# _p,mba_p)

# %%
from scipy.stats import ttest_ind
# null value drop
degree=dataset.dropna()
degree=dataset[dataset['degree_t']=='Sci&Tech']['etest_p']
degree1=dataset[dataset['degree_t']=='Sci&Tech']['mba_p']
# print(male)
ttest_ind(degree,degree1)
# Out:
# Ttest_indResult(statistic=4.532000225151251, pvalue=1.4289217003775636e-05)

# %% [markdown]
# Hypothesis Report
#
# H0 = There is no similarity between degree_t(Sci&Tech) with respect to etest_p and mba_p.
#
# H1 = There is a similarity between degree_t(Sci&Tech) with respect to etest_p and mba_p.
#
# Accept the null hypothesis and reject the alternative hypothesis.
#
# The statistic = 4.53; there is a significant similarity between degree_t(Sci&Tech), etest_p, and mba_p, and the p-value < 0.05%.

# %% [markdown]
# # 12)Which parameter is highly correlated with salary ?

# %%
dataset.corr(numeric_only=True)
# Out:
#              ssc_p     hsc_p  degree_p   etest_p     mba_p    salary
# ssc_p     1.000000  0.511472  0.538404  0.261993  0.388478  0.538090
# hsc_p     0.511472  1.000000  0.434206  0.245113  0.354823  0.452569
# degree_p  0.538404  0.434206  1.000000  0.224470  0.402364  0.408371
# etest_p   0.261993  0.245113  0.224470  1.000000  0.218055  0.186988
# mba_p     0.388478  0.354823  0.402364  0.218055  1.000000  0.139823
# salary    0.538090  0.452569  0.408371  0.186988  0.139823  1.000000

# %% [markdown]
# The highly correlated SSC_P mark with salary.

# %% [markdown]
# #  13)Plot any useful graph and explain it

# %%
# Visulaize the pa
import seaborn as sns
#pairplot is for 2 columns
sns.pairplot(dataset)
# Out:
# C:\Users\DELL\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\DELL\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\DELL\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %%
sns.pairplot(dataset,hue='gender',diag_kind="kde",kind='script',palette="hus1")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\seaborn\palettes.py:235, in color_palette(palette, n_colors, desat, as_cmap)
#     233 try:
#     234     # Perhaps a named matplotlib colormap?
# --> 235     palette = mpl_palette(palette, n_colors, as_cmap=as_cmap)
#     236 except (ValueError, KeyError):  # Error class changed in mpl36
#
# File ~\anaconda3\Lib\site-packages\seaborn\palettes.py:406, in mpl_palette(name, n_colors, as_cmap)
#     405 else:
# --> 406     cmap = get_colormap(name)
#     408 if name in MPL_QUAL_PALS:
#
# File ~\anaconda3\Lib\site-packages\seaborn\_compat.py:133, in get_colormap(name)
#     132 try:
# --> 133     return mpl.colormaps[name]
#     134 except AttributeError:
#
# File ~\anaconda3\Lib\site-packages\matplotlib\cm.py:88, in ColormapRegistry.__getitem__(self, item)
#      87 except KeyError:
# ...
